# %% [markdown]
# # 7 WorkFlow

# %% [markdown]
# ### 7.1 Objetivo

# %% [markdown]
# Presentar un workflow/pipeline completo al que los estudiantes deberán enriquecer

# %% [markdown]
# #### 7.2  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab
# *   Bajar el **dataset_historico** al Google Drive y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %% [markdown]
# *  Si usted eligió modalidad *Gerencial* entonces NO debe modificar nada, su liderazgo logró que otras trabajaron por usted
# *  Si usted eligió modalidad de *Analista Junior*, entonces donde dice archivo="gerencial_competencia_2025.csv.gz"  lo debe cambiar por  archivo="analistajr_competencia_2025.csv.gz"
# *  Si usted eligió modalidad *Analista Senior*,  ya se las ingenierá SIN preguntar !

# %%
%%shell

mkdir -p "/content/.drive/My Drive/labo1"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/labo1" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets


webfiles="https://storage.googleapis.com/open-courses/austral2025-af91/labo1r"
destino_local="/content/datasets"
destino_bucket="/content/buckets/b1/datasets"


archivo="dataset_pequeno.csv"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi

#-------

archivo="gerencial_competencia_2025.csv.gz"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi

# %% [markdown]
# ## 7.3  Workflow

# %% [markdown]
# ## Inicializacion

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje **R** Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Tue Jun 10 18:31:29 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  653531 35.0 1439434    76.9 1383155  73.9
# Vcells 1218198  9.3 8388608    64.0 1924971  14.7

# %%
require("data.table")

if( !require("R.utils")) install.packages("R.utils")
require("R.utils")
# Out:
# Loading required package: data.table
#
# Loading required package: R.utils
#
# Loading required package: R.oo
#
# Loading required package: R.methodsS3
#
# R.methodsS3 v1.8.2 (2022-06-13 22:00:14 UTC) successfully loaded. See ?R.methodsS3 for help.
#
# R.oo v1.27.1 (2025-05-02 21:00:05 UTC) successfully loaded. See ?R.oo for help.
#
#
# Attaching package: ‘R.oo’
#
#
# The following object is masked from ‘package:R.methodsS3’:
#
#     throw
#
#
# The following objects are masked from ‘package:methods’:
#
#     getClasses, getMethods
#
#
# The following objects are masked from ‘package:base’:
#
#     attach, detach, load, save
#
#
# R.utils v2.13.0 (2025-02-24 21:20:02 UTC) successfully loaded. See ?R.utils for help.
#
#
# Attaching package: ‘R.utils’
#
#
# The following object is masked from ‘package:utils’:
#
#     timestamp
#
#
# The following objects are masked from ‘package:base’:
#
#     cat, commandArgs, getOption, isOpen, nullfile, parse, use, warnings

# %% [markdown]
# #### Parametros
# Si es gerente, no cambie nada
# <br>Si es Analista, cambie el nombre del dataset

# %%
PARAM <- list()
PARAM$semilla_primigenia <- 847117

PARAM$experimento <- 7300
PARAM$dataset <- "analistasr_competencia_2025.csv.gz"

# %% [markdown]
# #### Carpeta del Experimento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("WF", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %% [markdown]
# ### 7.3.1   Preprocesamiento del dataset

# %% [markdown]
# #### 7.3.1.1  DT incorporar dataset

# %%
# lectura del dataset
dataset <- fread(paste0("/content/datasets/", PARAM$dataset))

# %% [markdown]
# #### 7.3.1.2  CA  Catastrophe Analysis
# Se intentan reparar las variables que para un mes están con todos los valores en cero.

# %% [markdown]
# El método que se utiliza es **Machine Learning** se asigna NA also valores, si ha leido bien, es la "anti imputación de valores faltantes"
# <br> Usted podrá aplicar aquí otros métodos

# %%
dataset[ foto_mes==202006, internet:=NA]
dataset[ foto_mes==202006, mrentabilidad:=NA]
dataset[ foto_mes==202006, mrentabilidad_annual:=NA]
dataset[ foto_mes==202006, mcomisiones:=NA]
dataset[ foto_mes==202006, mactivos_margen:=NA]
dataset[ foto_mes==202006, mpasivos_margen:=NA]
dataset[ foto_mes==202006, mcuentas_saldo:=NA]
dataset[ foto_mes==202006, ctarjeta_visa_transacciones:=NA]
dataset[ foto_mes==202006, mtarjeta_visa_consumo:=NA]
dataset[ foto_mes==202006, mtarjeta_master_consumo:=NA]
dataset[ foto_mes==202006, ccallcenter_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]

# %% [markdown]
# #### 7.3.1.3  DR  Data Drifting
# Se intenta corregir el data drifting, quizas ajustando por IPC ...
# <br>Esta parte podrá ser abordada por todos los Analistas y también la Gerenciapero se decide pedagogicamente no incluirla en esta primer version para reducir la carga cognitiva

# %%
# sin codigo en esta primera version del workflow

# %% [markdown]
# #### 7.3.1.3  FE_intra_manual Feature Engineering intra-mes
#
# Agrego campos nuevos dentro del mismo mes, SIN considerar la historia.

# %%
# esta funcion atributos presentes existe debido a que las modalidades poseen datasets con distinta cantidad de campos
atributos_presentes <- function( patributos )
{
  atributos <- unique( patributos )
  comun <- intersect( atributos, colnames(dataset) )

  return(  length( atributos ) == length( comun ) )
}

# el mes 1,2, ..12
if( atributos_presentes( c("foto_mes") ))
  dataset[, kmes := foto_mes %% 100]

# variable extraida de una tesis de maestria de Irlanda
if( atributos_presentes( c("mpayroll", "cliente_edad") ))
  dataset[, mpayroll_sobre_edad := mpayroll / cliente_edad]

# %%
# visualizo las columas del dataset a esta etapa
colnames(dataset)
# Out:
#   [1] "numero_de_cliente"
#   [2] "foto_mes"
#   [3] "active_quarter"
#   [4] "cliente_vip"
#   [5] "internet"
#   [6] "cliente_edad"
#   [7] "cliente_antiguedad"
#   [8] "mrentabilidad"
#   [9] "mrentabilidad_annual"
#  [10] "mcomisiones"
#  [11] "mactivos_margen"
#  [12] "mpasivos_margen"
#  [13] "cproductos"
#  [14] "tcuentas"
#  [15] "ccuenta_corriente"
#  [16] "mcuenta_corriente_adicional"
#  [17] "mcuenta_corriente"
#  [18] "ccaja_ahorro"
#  [19] "mcaja_ahorro"
#  [20] "mcaja_ahorro_adicional"
#  [21] "mcaja_ahorro_dolares"
#  [22] "cdescubierto_preacordado"
#  [23] "mcuentas_saldo"
#  [24] "ctarjeta_debito"
#  [25] "ctarjeta_debito_transacciones"
#  [26] "mautoservicio"
#  [27] "ctarjeta_visa"
#  [28] "ctarjeta_visa_transacciones"
#  [29] "mtarjeta_visa_consumo"
#  [30] "ctarjeta_master"
#  [31] "ctarjeta_master_transacciones"
#  [32] "mtarjeta_master_consumo"
#  [33] "cprestamos_personales"
#  [34] "mprestamos_personales"
#  [35] "cprestamos_prendarios"
#  [36] "mprestamos_prendarios"
#  [37] "cprestamos_hipotecarios"
#  [38] "mprestamos_hipotecarios"
#  [39] "cplazo_fijo"
#  [40] "mplazo_fijo_dolares"
#  [41] "mplazo_fijo_pesos"
#  [42] "cinversion1"
#  [43] "minversion1_pesos"
#  [44] "minversion1_dolares"
#  [45] "cinversion2"
#  [46] "minversion2"
#  [47] "cseguro_vida"
#  [48] "cseguro_auto"
#  [49] "cseguro_vivienda"
#  [50] "cseguro_accidentes_personales"
#  [51] "ccaja_seguridad"
#  [52] "cpayroll_trx"
#  [53] "mpayroll"
#  [54] "mpayroll2"
#  [55] "cpayroll2_trx"
#  [56] "ccuenta_debitos_automaticos"
#  [57] "mcuenta_debitos_automaticos"
#  [58] "ctarjeta_visa_debitos_automaticos"
#  [59] "mttarjeta_visa_debitos_automaticos"
#  [60] "ctarjeta_master_debitos_automaticos"
#  [61] "mttarjeta_master_debitos_automaticos"
#  [62] "cpagodeservicios"
#  [63] "mpagodeservicios"
#  [64] "cpagomiscuentas"
#  [65] "mpagomiscuentas"
#  [66] "ccajeros_propios_descuentos"
#  [67] "mcajeros_propios_descuentos"
#  [68] "ctarjeta_visa_descuentos"
#  [69] "mtarjeta_visa_descuentos"
#  [70] "ctarjeta_master_descuentos"
#  [71] "mtarjeta_master_descuentos"
#  [72] "ccomisiones_mantenimiento"
#  [73] "mcomisiones_mantenimiento"
#  [74] "ccomisiones_otras"
#  [75] "mcomisiones_otras"
#  [76] "cforex"
#  [77] "cforex_buy"
#  [78] "mforex_buy"
#  [79] "cforex_sell"
#  [80] "mforex_sell"
#  [81] "ctransferencias_recibidas"
#  [82] "mtransferencias_recibidas"
#  [83] "ctransferencias_emitidas"
#  [84] "mtransferencias_emitidas"
#  [85] "cextraccion_autoservicio"
#  [86] "mextraccion_autoservicio"
#  [87] "ccheques_depositados"
#  [88] "mcheques_depositados"
#  [89] "ccheques_emitidos"
#  [90] "mcheques_emitidos"
#  [91] "ccheques_depositados_rechazados"
#  [92] "mcheques_depositados_rechazados"
#  [93] "ccheques_emitidos_rechazados"
#  [94] "mcheques_emitidos_rechazados"
#  [95] "tcallcenter"
#  [96] "ccallcenter_transacciones"
#  [97] "thomebanking"
#  [98] "chomebanking_transacciones"
#  [99] "ccajas_transacciones"
# [100] "ccajas_consultas"
# [101] "ccajas_depositos"
# [102] "ccajas_extracciones"
# [103] "ccajas_otras"
# [104] "catm_trx"
# [105] "matm"
# [106] "catm_trx_other"
# [107] "matm_other"
# [108] "ctrx_quarter"
# [109] "tmobile_app"
# [110] "cmobile_app_trx"
# [111] "Master_delinquency"
# [112] "Master_status"
# [113] "Master_mfinanciacion_limite"
# [114] "Master_Fvencimiento"
# [115] "Master_Finiciomora"
# [116] "Master_msaldototal"
# [117] "Master_msaldopesos"
# [118] "Master_msaldodolares"
# [119] "Master_mconsumospesos"
# [120] "Master_mconsumosdolares"
# [121] "Master_mlimitecompra"
# [122] "Master_madelantopesos"
# [123] "Master_madelantodolares"
# [124] "Master_fultimo_cierre"
# [125] "Master_mpagado"
# [126] "Master_mpagospesos"
# [127] "Master_mpagosdolares"
# [128] "Master_fechaalta"
# [129] "Master_mconsumototal"
# [130] "Master_cconsumos"
# [131] "Master_cadelantosefectivo"
# [132] "Master_mpagominimo"
# [133] "Visa_delinquency"
# [134] "Visa_status"
# [135] "Visa_mfinanciacion_limite"
# [136] "Visa_Fvencimiento"
# [137] "Visa_Finiciomora"
# [138] "Visa_msaldototal"
# [139] "Visa_msaldopesos"
# [140] "Visa_msaldodolares"
# [141] "Visa_mconsumospesos"
# [142] "Visa_mconsumosdolares"
# [143] "Visa_mlimitecompra"
# [144] "Visa_madelantopesos"
# [145] "Visa_madelantodolares"
# [146] "Visa_fultimo_cierre"
# [147] "Visa_mpagado"
# [148] "Visa_mpagospesos"
# [149] "Visa_mpagosdolares"
# [150] "Visa_fechaalta"
# [151] "Visa_mconsumototal"
# [152] "Visa_cconsumos"
# [153] "Visa_cadelantosefectivo"
# [154] "Visa_mpagominimo"
# [155] "clase_ternaria"
# [156] "kmes"
# [157] "mpayroll_sobre_edad"

# %% [markdown]
# #### 7.3.1.4  FE_rf Feature Engineering de nuevas variables a partir de hojas de Random Forest
#
# Esto se mostrará unicamente a la *modalidad Analista Sr*

# %%
# No se implementa Feature Engineering a partir de Random Forest

# %% [markdown]
# #### 7.3.1.5  FEhist Feature Engineering historico
#
# El Fature Engineering Histórico es la etapa que más aporta a la ganancia final, ya que enriquece cada registro del dataset con su historia.

# %% [markdown]
# Para cada campo del dataset original (*)
# se crean lo siguientes campos de a partir de la historia
# * lag1  lags de orden 1
# * delta1  =  valor actual - lag1
# * lag2  lags de orden 2
# * delta2  = valor actual - lag2
#
#
# (*) Excepto para los campos  <numero_de_cliente,  foto_mes,  clase_ternaria>

# %%
# Feature Engineering Historico

# todo es lagueable, menos la primary key y la clase
cols_lagueables <- copy( setdiff(
    colnames(dataset),
    c("numero_de_cliente", "foto_mes", "clase_ternaria")
) )

# https://rdrr.io/cran/data.table/man/shift.html

# lags de orden 1
dataset[,
    paste0(cols_lagueables, "_lag1") := shift(.SD, 1, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# lags de orden 2
dataset[,
    paste0(cols_lagueables, "_lag2") := shift(.SD, 2, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# agrego los delta lags
for (vcol in cols_lagueables)
{
    dataset[, paste0(vcol, "_delta1") := get(vcol) - get(paste0(vcol, "_lag1"))]
    dataset[, paste0(vcol, "_delta2") := get(vcol) - get(paste0(vcol, "_lag2"))]
}

# %% [markdown]
# Verificacion de los campos recien creados

# %%
ncol(dataset)
colnames(dataset)
# Out:
# [1] 773
#   [1] "numero_de_cliente"
#   [2] "foto_mes"
#   [3] "active_quarter"
#   [4] "cliente_vip"
#   [5] "internet"
#   [6] "cliente_edad"
#   [7] "cliente_antiguedad"
#   [8] "mrentabilidad"
#   [9] "mrentabilidad_annual"
#  [10] "mcomisiones"
#  [11] "mactivos_margen"
#  [12] "mpasivos_margen"
#  [13] "cproductos"
#  [14] "tcuentas"
#  [15] "ccuenta_corriente"
#  [16] "mcuenta_corriente_adicional"
#  [17] "mcuenta_corriente"
#  [18] "ccaja_ahorro"
#  [19] "mcaja_ahorro"
#  [20] "mcaja_ahorro_adicional"
#  [21] "mcaja_ahorro_dolares"
#  [22] "cdescubierto_preacordado"
#  [23] "mcuentas_saldo"
#  [24] "ctarjeta_debito"
#  [25] "ctarjeta_debito_transacciones"
#  [26] "mautoservicio"
#  [27] "ctarjeta_visa"
#  [28] "ctarjeta_visa_transacciones"
#  [29] "mtarjeta_visa_consumo"
#  [30] "ctarjeta_master"
#  [31] "ctarjeta_master_transacciones"
#  [32] "mtarjeta_master_consumo"
#  [33] "cprestamos_personales"
#  [34] "mprestamos_personales"
#  [35] "cprestamos_prendarios"
#  [36] "mprestamos_prendarios"
#  [37] "cprestamos_hipotecarios"
#  [38] "mprestamos_hipotecarios"
#  [39] "cplazo_fijo"
#  [40] "mplazo_fijo_dolares"
#  [41] "mplazo_fijo_pesos"
#  [42] "cinversion1"
#  [43] "minversion1_pesos"
#  [44] "minversion1_dolares"
#  [45] "cinversion2"
#  [46] "minversion2"
#  [47] "cseguro_vida"
#  [48] "cseguro_auto"
#  [49] "cseguro_vivienda"
#  [50] "cseguro_accidentes_personales"
#  [51] "ccaja_seguridad"
#  [52] "cpayroll_trx"
#  [53] "mpayroll"
#  [54] "mpayroll2"
#  [55] "cpayroll2_trx"
#  [56] "ccuenta_debitos_automaticos"
#  [57] "mcuenta_debitos_automaticos"
#  [58] "ctarjeta_visa_debitos_automaticos"
#  [59] "mttarjeta_visa_debitos_automaticos"
#  [60] "ctarjeta_master_debitos_automaticos"
#  [61] "mttarjeta_master_debitos_automaticos"
#  [62] "cpagodeservicios"
#  [63] "mpagodeservicios"
#  [64] "cpagomiscuentas"
#  [65] "mpagomiscuentas"
#  [66] "ccajeros_propios_descuentos"
#  [67] "mcajeros_propios_descuentos"
#  [68] "ctarjeta_visa_descuentos"
#  [69] "mtarjeta_visa_descuentos"
#  [70] "ctarjeta_master_descuentos"
#  [71] "mtarjeta_master_descuentos"
#  [72] "ccomisiones_mantenimiento"
#  [73] "mcomisiones_mantenimiento"
#  [74] "ccomisiones_otras"
#  [75] "mcomisiones_otras"
#  [76] "cforex"
#  [77] "cforex_buy"
#  [78] "mforex_buy"
#  [79] "cforex_sell"
#  [80] "mforex_sell"
#  [81] "ctransferencias_recibidas"
#  [82] "mtransferencias_recibidas"
#  [83] "ctransferencias_emitidas"
#  [84] "mtransferencias_emitidas"
#  [85] "cextraccion_autoservicio"
#  [86] "mextraccion_autoservicio"
#  [87] "ccheques_depositados"
#  [88] "mcheques_depositados"
#  [89] "ccheques_emitidos"
#  [90] "mcheques_emitidos"
#  [91] "ccheques_depositados_rechazados"
#  [92] "mcheques_depositados_rechazados"
#  [93] "ccheques_emitidos_rechazados"
#  [94] "mcheques_emitidos_rechazados"
#  [95] "tcallcenter"
#  [96] "ccallcenter_transacciones"
#  [97] "thomebanking"
#  [98] "chomebanking_transacciones"
#  [99] "ccajas_transacciones"
# [100] "ccajas_consultas"
# [101] "ccajas_depositos"
# [102] "ccajas_extracciones"
# [103] "ccajas_otras"
# [104] "catm_trx"
# [105] "matm"
# [106] "catm_trx_other"
# [107] "matm_other"
# [108] "ctrx_quarter"
# [109] "tmobile_app"
# [110] "cmobile_app_trx"
# [111] "Master_delinquency"
# [112] "Master_status"
# [113] "Master_mfinanciacion_limite"
# [114] "Master_Fvencimiento"
# [115] "Master_Finiciomora"
# [116] "Master_msaldototal"
# [117] "Master_msaldopesos"
# [118] "Master_msaldodolares"
# [119] "Master_mconsumospesos"
# [120] "Master_mconsumosdolares"
# [121] "Master_mlimitecompra"
# [122] "Master_madelantopesos"
# [123] "Master_madelantodolares"
# [124] "Master_fultimo_cierre"
# [125] "Master_mpagado"
# [126] "Master_mpagospesos"
# [127] "Master_mpagosdolares"
# [128] "Master_fechaalta"
# [129] "Master_mconsumototal"
# [130] "Master_cconsumos"
# [131] "Master_cadelantosefectivo"
# [132] "Master_mpagominimo"
# [133] "Visa_delinquency"
# [134] "Visa_status"
# [135] "Visa_mfinanciacion_limite"
# [136] "Visa_Fvencimiento"
# [137] "Visa_Finiciomora"
# [138] "Visa_msaldototal"
# [139] "Visa_msaldopesos"
# [140] "Visa_msaldodolares"
# [141] "Visa_mconsumospesos"
# [142] "Visa_mconsumosdolares"
# [143] "Visa_mlimitecompra"
# [144] "Visa_madelantopesos"
# [145] "Visa_madelantodolares"
# [146] "Visa_fultimo_cierre"
# [147] "Visa_mpagado"
# [148] "Visa_mpagospesos"
# [149] "Visa_mpagosdolares"
# [150] "Visa_fechaalta"
# [151] "Visa_mconsumototal"
# [152] "Visa_cconsumos"
# [153] "Visa_cadelantosefectivo"
# [154] "Visa_mpagominimo"
# [155] "clase_ternaria"
# [156] "kmes"
# [157] "mpayroll_sobre_edad"
# [158] "active_quarter_lag1"
# [159] "cliente_vip_lag1"
# [160] "internet_lag1"
# [161] "cliente_edad_lag1"
# [162] "cliente_antiguedad_lag1"
# [163] "mrentabilidad_lag1"
# [164] "mrentabilidad_annual_lag1"
# [165] "mcomisiones_lag1"
# [166] "mactivos_margen_lag1"
# [167] "mpasivos_margen_lag1"
# [168] "cproductos_lag1"
# [169] "tcuentas_lag1"
# [170] "ccuenta_corriente_lag1"
# [171] "mcuenta_corriente_adicional_lag1"
# [172] "mcuenta_corriente_lag1"
# [173] "ccaja_ahorro_lag1"
# [174] "mcaja_ahorro_lag1"
# [175] "mcaja_ahorro_adicional_lag1"
# [176] "mcaja_ahorro_dolares_lag1"
# [177] "cdescubierto_preacordado_lag1"
# [178] "mcuentas_saldo_lag1"
# [179] "ctarjeta_debito_lag1"
# [180] "ctarjeta_debito_transacciones_lag1"
# [181] "mautoservicio_lag1"
# [182] "ctarjeta_visa_lag1"
# [183] "ctarjeta_visa_transacciones_lag1"
# [184] "mtarjeta_visa_consumo_lag1"
# [185] "ctarjeta_master_lag1"
# [186] "ctarjeta_master_transacciones_lag1"
# [187] "mtarjeta_master_consumo_lag1"
# [188] "cprestamos_personales_lag1"
# [189] "mprestamos_personales_lag1"
# [190] "cprestamos_prendarios_lag1"
# [191] "mprestamos_prendarios_lag1"
# [192] "cprestamos_hipotecarios_lag1"
# [193] "mprestamos_hipotecarios_lag1"
# [194] "cplazo_fijo_lag1"
# [195] "mplazo_fijo_dolares_lag1"
# [196] "mplazo_fijo_pesos_lag1"
# [197] "cinversion1_lag1"
# [198] "minversion1_pesos_lag1"
# [199] "minversion1_dolares_lag1"
# [200] "cinversion2_lag1"
# [201] "minversion2_lag1"
# [202] "cseguro_vida_lag1"
# [203] "cseguro_auto_lag1"
# [204] "cseguro_vivienda_lag1"
# [205] "cseguro_accidentes_personales_lag1"
# [206] "ccaja_seguridad_lag1"
# [207] "cpayroll_trx_lag1"
# [208] "mpayroll_lag1"
# [209] "mpayroll2_lag1"
# [210] "cpayroll2_trx_lag1"
# [211] "ccuenta_debitos_automaticos_lag1"
# [212] "mcuenta_debitos_automaticos_lag1"
# [213] "ctarjeta_visa_debitos_automaticos_lag1"
# [214] "mttarjeta_visa_debitos_automaticos_lag1"
# [215] "ctarjeta_master_debitos_automaticos_lag1"
# [216] "mttarjeta_master_debitos_automaticos_lag1"
# [217] "cpagodeservicios_lag1"
# [218] "mpagodeservicios_lag1"
# [219] "cpagomiscuentas_lag1"
# [220] "mpagomiscuentas_lag1"
# [221] "ccajeros_propios_descuentos_lag1"
# [222] "mcajeros_propios_descuentos_lag1"
# [223] "ctarjeta_visa_descuentos_lag1"
# [224] "mtarjeta_visa_descuentos_lag1"
# [225] "ctarjeta_master_descuentos_lag1"
# [226] "mtarjeta_master_descuentos_lag1"
# [227] "ccomisiones_mantenimiento_lag1"
# [228] "mcomisiones_mantenimiento_lag1"
# [229] "ccomisiones_otras_lag1"
# [230] "mcomisiones_otras_lag1"
# [231] "cforex_lag1"
# [232] "cforex_buy_lag1"
# [233] "mforex_buy_lag1"
# [234] "cforex_sell_lag1"
# [235] "mforex_sell_lag1"
# [236] "ctransferencias_recibidas_lag1"
# [237] "mtransferencias_recibidas_lag1"
# [238] "ctransferencias_emitidas_lag1"
# [239] "mtransferencias_emitidas_lag1"
# [240] "cextraccion_autoservicio_lag1"
# [241] "mextraccion_autoservicio_lag1"
# [242] "ccheques_depositados_lag1"
# [243] "mcheques_depositados_lag1"
# [244] "ccheques_emitidos_lag1"
# [245] "mcheques_emitidos_lag1"
# [246] "ccheques_depositados_rechazados_lag1"
# [247] "mcheques_depositados_rechazados_lag1"
# [248] "ccheques_emitidos_rechazados_lag1"
# [249] "mcheques_emitidos_rechazados_lag1"
# [250] "tcallcenter_lag1"
# [251] "ccallcenter_transacciones_lag1"
# [252] "thomebanking_lag1"
# [253] "chomebanking_transacciones_lag1"
# [254] "ccajas_transacciones_lag1"
# [255] "ccajas_consultas_lag1"
# [256] "ccajas_depositos_lag1"
# [257] "ccajas_extracciones_lag1"
# [258] "ccajas_otras_lag1"
# [259] "catm_trx_lag1"
# [260] "matm_lag1"
# [261] "catm_trx_other_lag1"
# [262] "matm_other_lag1"
# [263] "ctrx_quarter_lag1"
# [264] "tmobile_app_lag1"
# [265] "cmobile_app_trx_lag1"
# [266] "Master_delinquency_lag1"
# [267] "Master_status_lag1"
# [268] "Master_mfinanciacion_limite_lag1"
# [269] "Master_Fvencimiento_lag1"
# [270] "Master_Finiciomora_lag1"
# [271] "Master_msaldototal_lag1"
# [272] "Master_msaldopesos_lag1"
# [273] "Master_msaldodolares_lag1"
# [274] "Master_mconsumospesos_lag1"
# [275] "Master_mconsumosdolares_lag1"
# [276] "Master_mlimitecompra_lag1"
# [277] "Master_madelantopesos_lag1"
# [278] "Master_madelantodolares_lag1"
# [279] "Master_fultimo_cierre_lag1"
# [280] "Master_mpagado_lag1"
# [281] "Master_mpagospesos_lag1"
# [282] "Master_mpagosdolares_lag1"
# [283] "Master_fechaalta_lag1"
# [284] "Master_mconsumototal_lag1"
# [285] "Master_cconsumos_lag1"
# [286] "Master_cadelantosefectivo_lag1"
# [287] "Master_mpagominimo_lag1"
# [288] "Visa_delinquency_lag1"
# [289] "Visa_status_lag1"
# [290] "Visa_mfinanciacion_limite_lag1"
# [291] "Visa_Fvencimiento_lag1"
# [292] "Visa_Finiciomora_lag1"
# [293] "Visa_msaldototal_lag1"
# [294] "Visa_msaldopesos_lag1"
# [295] "Visa_msaldodolares_lag1"
# [296] "Visa_mconsumospesos_lag1"
# [297] "Visa_mconsumosdolares_lag1"
# [298] "Visa_mlimitecompra_lag1"
# [299] "Visa_madelantopesos_lag1"
# [300] "Visa_madelantodolares_lag1"
# [301] "Visa_fultimo_cierre_lag1"
# [302] "Visa_mpagado_lag1"
# [303] "Visa_mpagospesos_lag1"
# [304] "Visa_mpagosdolares_lag1"
# [305] "Visa_fechaalta_lag1"
# [306] "Visa_mconsumototal_lag1"
# [307] "Visa_cconsumos_lag1"
# [308] "Visa_cadelantosefectivo_lag1"
# [309] "Visa_mpagominimo_lag1"
# [310] "kmes_lag1"
# [311] "mpayroll_sobre_edad_lag1"
# [312] "active_quarter_lag2"
# [313] "cliente_vip_lag2"
# [314] "internet_lag2"
# [315] "cliente_edad_lag2"
# [316] "cliente_antiguedad_lag2"
# [317] "mrentabilidad_lag2"
# [318] "mrentabilidad_annual_lag2"
# [319] "mcomisiones_lag2"
# [320] "mactivos_margen_lag2"
# [321] "mpasivos_margen_lag2"
# [322] "cproductos_lag2"
# [323] "tcuentas_lag2"
# [324] "ccuenta_corriente_lag2"
# [325] "mcuenta_corriente_adicional_lag2"
# [326] "mcuenta_corriente_lag2"
# [327] "ccaja_ahorro_lag2"
# [328] "mcaja_ahorro_lag2"
# [329] "mcaja_ahorro_adicional_lag2"
# [330] "mcaja_ahorro_dolares_lag2"
# [331] "cdescubierto_preacordado_lag2"
# [332] "mcuentas_saldo_lag2"
# [333] "ctarjeta_debito_lag2"
# [334] "ctarjeta_debito_transacciones_lag2"
# [335] "mautoservicio_lag2"
# [336] "ctarjeta_visa_lag2"
# [337] "ctarjeta_visa_transacciones_lag2"
# [338] "mtarjeta_visa_consumo_lag2"
# [339] "ctarjeta_master_lag2"
# [340] "ctarjeta_master_transacciones_lag2"
# [341] "mtarjeta_master_consumo_lag2"
# [342] "cprestamos_personales_lag2"
# [343] "mprestamos_personales_lag2"
# [344] "cprestamos_prendarios_lag2"
# [345] "mprestamos_prendarios_lag2"
# [346] "cprestamos_hipotecarios_lag2"
# [347] "mprestamos_hipotecarios_lag2"
# [348] "cplazo_fijo_lag2"
# [349] "mplazo_fijo_dolares_lag2"
# [350] "mplazo_fijo_pesos_lag2"
# [351] "cinversion1_lag2"
# [352] "minversion1_pesos_lag2"
# [353] "minversion1_dolares_lag2"
# [354] "cinversion2_lag2"
# [355] "minversion2_lag2"
# [356] "cseguro_vida_lag2"
# [357] "cseguro_auto_lag2"
# [358] "cseguro_vivienda_lag2"
# [359] "cseguro_accidentes_personales_lag2"
# [360] "ccaja_seguridad_lag2"
# [361] "cpayroll_trx_lag2"
# [362] "mpayroll_lag2"
# [363] "mpayroll2_lag2"
# [364] "cpayroll2_trx_lag2"
# [365] "ccuenta_debitos_automaticos_lag2"
# [366] "mcuenta_debitos_automaticos_lag2"
# [367] "ctarjeta_visa_debitos_automaticos_lag2"
# [368] "mttarjeta_visa_debitos_automaticos_lag2"
# [369] "ctarjeta_master_debitos_automaticos_lag2"
# [370] "mttarjeta_master_debitos_automaticos_lag2"
# [371] "cpagodeservicios_lag2"
# [372] "mpagodeservicios_lag2"
# [373] "cpagomiscuentas_lag2"
# [374] "mpagomiscuentas_lag2"
# [375] "ccajeros_propios_descuentos_lag2"
# [376] "mcajeros_propios_descuentos_lag2"
# [377] "ctarjeta_visa_descuentos_lag2"
# [378] "mtarjeta_visa_descuentos_lag2"
# [379] "ctarjeta_master_descuentos_lag2"
# [380] "mtarjeta_master_descuentos_lag2"
# [381] "ccomisiones_mantenimiento_lag2"
# [382] "mcomisiones_mantenimiento_lag2"
# [383] "ccomisiones_otras_lag2"
# [384] "mcomisiones_otras_lag2"
# [385] "cforex_lag2"
# [386] "cforex_buy_lag2"
# [387] "mforex_buy_lag2"
# [388] "cforex_sell_lag2"
# [389] "mforex_sell_lag2"
# [390] "ctransferencias_recibidas_lag2"
# [391] "mtransferencias_recibidas_lag2"
# [392] "ctransferencias_emitidas_lag2"
# [393] "mtransferencias_emitidas_lag2"
# [394] "cextraccion_autoservicio_lag2"
# [395] "mextraccion_autoservicio_lag2"
# [396] "ccheques_depositados_lag2"
# [397] "mcheques_depositados_lag2"
# [398] "ccheques_emitidos_lag2"
# [399] "mcheques_emitidos_lag2"
# [400] "ccheques_depositados_rechazados_lag2"
# [401] "mcheques_depositados_rechazados_lag2"
# [402] "ccheques_emitidos_rechazados_lag2"
# [403] "mcheques_emitidos_rechazados_lag2"
# [404] "tcallcenter_lag2"
# [405] "ccallcenter_transacciones_lag2"
# [406] "thomebanking_lag2"
# [407] "chomebanking_transacciones_lag2"
# [408] "ccajas_transacciones_lag2"
# [409] "ccajas_consultas_lag2"
# [410] "ccajas_depositos_lag2"
# [411] "ccajas_extracciones_lag2"
# [412] "ccajas_otras_lag2"
# [413] "catm_trx_lag2"
# [414] "matm_lag2"
# [415] "catm_trx_other_lag2"
# [416] "matm_other_lag2"
# [417] "ctrx_quarter_lag2"
# [418] "tmobile_app_lag2"
# [419] "cmobile_app_trx_lag2"
# [420] "Master_delinquency_lag2"
# [421] "Master_status_lag2"
# [422] "Master_mfinanciacion_limite_lag2"
# [423] "Master_Fvencimiento_lag2"
# [424] "Master_Finiciomora_lag2"
# [425] "Master_msaldototal_lag2"
# [426] "Master_msaldopesos_lag2"
# [427] "Master_msaldodolares_lag2"
# [428] "Master_mconsumospesos_lag2"
# [429] "Master_mconsumosdolares_lag2"
# [430] "Master_mlimitecompra_lag2"
# [431] "Master_madelantopesos_lag2"
# [432] "Master_madelantodolares_lag2"
# [433] "Master_fultimo_cierre_lag2"
# [434] "Master_mpagado_lag2"
# [435] "Master_mpagospesos_lag2"
# [436] "Master_mpagosdolares_lag2"
# [437] "Master_fechaalta_lag2"
# [438] "Master_mconsumototal_lag2"
# [439] "Master_cconsumos_lag2"
# [440] "Master_cadelantosefectivo_lag2"
# [441] "Master_mpagominimo_lag2"
# [442] "Visa_delinquency_lag2"
# [443] "Visa_status_lag2"
# [444] "Visa_mfinanciacion_limite_lag2"
# [445] "Visa_Fvencimiento_lag2"
# [446] "Visa_Finiciomora_lag2"
# [447] "Visa_msaldototal_lag2"
# [448] "Visa_msaldopesos_lag2"
# [449] "Visa_msaldodolares_lag2"
# [450] "Visa_mconsumospesos_lag2"
# [451] "Visa_mconsumosdolares_lag2"
# [452] "Visa_mlimitecompra_lag2"
# [453] "Visa_madelantopesos_lag2"
# [454] "Visa_madelantodolares_lag2"
# [455] "Visa_fultimo_cierre_lag2"
# [456] "Visa_mpagado_lag2"
# [457] "Visa_mpagospesos_lag2"
# [458] "Visa_mpagosdolares_lag2"
# [459] "Visa_fechaalta_lag2"
# [460] "Visa_mconsumototal_lag2"
# [461] "Visa_cconsumos_lag2"
# [462] "Visa_cadelantosefectivo_lag2"
# [463] "Visa_mpagominimo_lag2"
# [464] "kmes_lag2"
# [465] "mpayroll_sobre_edad_lag2"
# [466] "active_quarter_delta1"
# [467] "active_quarter_delta2"
# [468] "cliente_vip_delta1"
# [469] "cliente_vip_delta2"
# [470] "internet_delta1"
# [471] "internet_delta2"
# [472] "cliente_edad_delta1"
# [473] "cliente_edad_delta2"
# [474] "cliente_antiguedad_delta1"
# [475] "cliente_antiguedad_delta2"
# [476] "mrentabilidad_delta1"
# [477] "mrentabilidad_delta2"
# [478] "mrentabilidad_annual_delta1"
# [479] "mrentabilidad_annual_delta2"
# [480] "mcomisiones_delta1"
# [481] "mcomisiones_delta2"
# [482] "mactivos_margen_delta1"
# [483] "mactivos_margen_delta2"
# [484] "mpasivos_margen_delta1"
# [485] "mpasivos_margen_delta2"
# [486] "cproductos_delta1"
# [487] "cproductos_delta2"
# [488] "tcuentas_delta1"
# [489] "tcuentas_delta2"
# [490] "ccuenta_corriente_delta1"
# [491] "ccuenta_corriente_delta2"
# [492] "mcuenta_corriente_adicional_delta1"
# [493] "mcuenta_corriente_adicional_delta2"
# [494] "mcuenta_corriente_delta1"
# [495] "mcuenta_corriente_delta2"
# [496] "ccaja_ahorro_delta1"
# [497] "ccaja_ahorro_delta2"
# [498] "mcaja_ahorro_delta1"
# [499] "mcaja_ahorro_delta2"
# [500] "mcaja_ahorro_adicional_delta1"
# [501] "mcaja_ahorro_adicional_delta2"
# [502] "mcaja_ahorro_dolares_delta1"
# [503] "mcaja_ahorro_dolares_delta2"
# [504] "cdescubierto_preacordado_delta1"
# [505] "cdescubierto_preacordado_delta2"
# [506] "mcuentas_saldo_delta1"
# [507] "mcuentas_saldo_delta2"
# [508] "ctarjeta_debito_delta1"
# [509] "ctarjeta_debito_delta2"
# [510] "ctarjeta_debito_transacciones_delta1"
# [511] "ctarjeta_debito_transacciones_delta2"
# [512] "mautoservicio_delta1"
# [513] "mautoservicio_delta2"
# [514] "ctarjeta_visa_delta1"
# [515] "ctarjeta_visa_delta2"
# [516] "ctarjeta_visa_transacciones_delta1"
# [517] "ctarjeta_visa_transacciones_delta2"
# [518] "mtarjeta_visa_consumo_delta1"
# [519] "mtarjeta_visa_consumo_delta2"
# [520] "ctarjeta_master_delta1"
# [521] "ctarjeta_master_delta2"
# [522] "ctarjeta_master_transacciones_delta1"
# [523] "ctarjeta_master_transacciones_delta2"
# [524] "mtarjeta_master_consumo_delta1"
# [525] "mtarjeta_master_consumo_delta2"
# [526] "cprestamos_personales_delta1"
# [527] "cprestamos_personales_delta2"
# [528] "mprestamos_personales_delta1"
# [529] "mprestamos_personales_delta2"
# [530] "cprestamos_prendarios_delta1"
# [531] "cprestamos_prendarios_delta2"
# [532] "mprestamos_prendarios_delta1"
# [533] "mprestamos_prendarios_delta2"
# [534] "cprestamos_hipotecarios_delta1"
# [535] "cprestamos_hipotecarios_delta2"
# [536] "mprestamos_hipotecarios_delta1"
# [537] "mprestamos_hipotecarios_delta2"
# [538] "cplazo_fijo_delta1"
# [539] "cplazo_fijo_delta2"
# [540] "mplazo_fijo_dolares_delta1"
# [541] "mplazo_fijo_dolares_delta2"
# [542] "mplazo_fijo_pesos_delta1"
# [543] "mplazo_fijo_pesos_delta2"
# [544] "cinversion1_delta1"
# [545] "cinversion1_delta2"
# [546] "minversion1_pesos_delta1"
# [547] "minversion1_pesos_delta2"
# [548] "minversion1_dolares_delta1"
# [549] "minversion1_dolares_delta2"
# [550] "cinversion2_delta1"
# [551] "cinversion2_delta2"
# [552] "minversion2_delta1"
# [553] "minversion2_delta2"
# [554] "cseguro_vida_delta1"
# [555] "cseguro_vida_delta2"
# [556] "cseguro_auto_delta1"
# [557] "cseguro_auto_delta2"
# [558] "cseguro_vivienda_delta1"
# [559] "cseguro_vivienda_delta2"
# [560] "cseguro_accidentes_personales_delta1"
# [561] "cseguro_accidentes_personales_delta2"
# [562] "ccaja_seguridad_delta1"
# [563] "ccaja_seguridad_delta2"
# [564] "cpayroll_trx_delta1"
# [565] "cpayroll_trx_delta2"
# [566] "mpayroll_delta1"
# [567] "mpayroll_delta2"
# [568] "mpayroll2_delta1"
# [569] "mpayroll2_delta2"
# [570] "cpayroll2_trx_delta1"
# [571] "cpayroll2_trx_delta2"
# [572] "ccuenta_debitos_automaticos_delta1"
# [573] "ccuenta_debitos_automaticos_delta2"
# [574] "mcuenta_debitos_automaticos_delta1"
# [575] "mcuenta_debitos_automaticos_delta2"
# [576] "ctarjeta_visa_debitos_automaticos_delta1"
# [577] "ctarjeta_visa_debitos_automaticos_delta2"
# [578] "mttarjeta_visa_debitos_automaticos_delta1"
# [579] "mttarjeta_visa_debitos_automaticos_delta2"
# [580] "ctarjeta_master_debitos_automaticos_delta1"
# [581] "ctarjeta_master_debitos_automaticos_delta2"
# [582] "mttarjeta_master_debitos_automaticos_delta1"
# [583] "mttarjeta_master_debitos_automaticos_delta2"
# [584] "cpagodeservicios_delta1"
# [585] "cpagodeservicios_delta2"
# [586] "mpagodeservicios_delta1"
# [587] "mpagodeservicios_delta2"
# [588] "cpagomiscuentas_delta1"
# [589] "cpagomiscuentas_delta2"
# [590] "mpagomiscuentas_delta1"
# [591] "mpagomiscuentas_delta2"
# [592] "ccajeros_propios_descuentos_delta1"
# [593] "ccajeros_propios_descuentos_delta2"
# [594] "mcajeros_propios_descuentos_delta1"
# [595] "mcajeros_propios_descuentos_delta2"
# [596] "ctarjeta_visa_descuentos_delta1"
# [597] "ctarjeta_visa_descuentos_delta2"
# [598] "mtarjeta_visa_descuentos_delta1"
# [599] "mtarjeta_visa_descuentos_delta2"
# [600] "ctarjeta_master_descuentos_delta1"
# [601] "ctarjeta_master_descuentos_delta2"
# [602] "mtarjeta_master_descuentos_delta1"
# [603] "mtarjeta_master_descuentos_delta2"
# [604] "ccomisiones_mantenimiento_delta1"
# [605] "ccomisiones_mantenimiento_delta2"
# [606] "mcomisiones_mantenimiento_delta1"
# [607] "mcomisiones_mantenimiento_delta2"
# [608] "ccomisiones_otras_delta1"
# [609] "ccomisiones_otras_delta2"
# [610] "mcomisiones_otras_delta1"
# [611] "mcomisiones_otras_delta2"
# [612] "cforex_delta1"
# [613] "cforex_delta2"
# [614] "cforex_buy_delta1"
# [615] "cforex_buy_delta2"
# [616] "mforex_buy_delta1"
# [617] "mforex_buy_delta2"
# [618] "cforex_sell_delta1"
# [619] "cforex_sell_delta2"
# [620] "mforex_sell_delta1"
# [621] "mforex_sell_delta2"
# [622] "ctransferencias_recibidas_delta1"
# [623] "ctransferencias_recibidas_delta2"
# [624] "mtransferencias_recibidas_delta1"
# [625] "mtransferencias_recibidas_delta2"
# [626] "ctransferencias_emitidas_delta1"
# [627] "ctransferencias_emitidas_delta2"
# [628] "mtransferencias_emitidas_delta1"
# [629] "mtransferencias_emitidas_delta2"
# [630] "cextraccion_autoservicio_delta1"
# [631] "cextraccion_autoservicio_delta2"
# [632] "mextraccion_autoservicio_delta1"
# [633] "mextraccion_autoservicio_delta2"
# [634] "ccheques_depositados_delta1"
# [635] "ccheques_depositados_delta2"
# [636] "mcheques_depositados_delta1"
# [637] "mcheques_depositados_delta2"
# [638] "ccheques_emitidos_delta1"
# [639] "ccheques_emitidos_delta2"
# [640] "mcheques_emitidos_delta1"
# [641] "mcheques_emitidos_delta2"
# [642] "ccheques_depositados_rechazados_delta1"
# [643] "ccheques_depositados_rechazados_delta2"
# [644] "mcheques_depositados_rechazados_delta1"
# [645] "mcheques_depositados_rechazados_delta2"
# [646] "ccheques_emitidos_rechazados_delta1"
# [647] "ccheques_emitidos_rechazados_delta2"
# [648] "mcheques_emitidos_rechazados_delta1"
# [649] "mcheques_emitidos_rechazados_delta2"
# [650] "tcallcenter_delta1"
# [651] "tcallcenter_delta2"
# [652] "ccallcenter_transacciones_delta1"
# [653] "ccallcenter_transacciones_delta2"
# [654] "thomebanking_delta1"
# [655] "thomebanking_delta2"
# [656] "chomebanking_transacciones_delta1"
# [657] "chomebanking_transacciones_delta2"
# [658] "ccajas_transacciones_delta1"
# [659] "ccajas_transacciones_delta2"
# [660] "ccajas_consultas_delta1"
# [661] "ccajas_consultas_delta2"
# [662] "ccajas_depositos_delta1"
# [663] "ccajas_depositos_delta2"
# [664] "ccajas_extracciones_delta1"
# [665] "ccajas_extracciones_delta2"
# [666] "ccajas_otras_delta1"
# [667] "ccajas_otras_delta2"
# [668] "catm_trx_delta1"
# [669] "catm_trx_delta2"
# [670] "matm_delta1"
# [671] "matm_delta2"
# [672] "catm_trx_other_delta1"
# [673] "catm_trx_other_delta2"
# [674] "matm_other_delta1"
# [675] "matm_other_delta2"
# [676] "ctrx_quarter_delta1"
# [677] "ctrx_quarter_delta2"
# [678] "tmobile_app_delta1"
# [679] "tmobile_app_delta2"
# [680] "cmobile_app_trx_delta1"
# [681] "cmobile_app_trx_delta2"
# [682] "Master_delinquency_delta1"
# [683] "Master_delinquency_delta2"
# [684] "Master_status_delta1"
# [685] "Master_status_delta2"
# [686] "Master_mfinanciacion_limite_delta1"
# [687] "Master_mfinanciacion_limite_delta2"
# [688] "Master_Fvencimiento_delta1"
# [689] "Master_Fvencimiento_delta2"
# [690] "Master_Finiciomora_delta1"
# [691] "Master_Finiciomora_delta2"
# [692] "Master_msaldototal_delta1"
# [693] "Master_msaldototal_delta2"
# [694] "Master_msaldopesos_delta1"
# [695] "Master_msaldopesos_delta2"
# [696] "Master_msaldodolares_delta1"
# [697] "Master_msaldodolares_delta2"
# [698] "Master_mconsumospesos_delta1"
# [699] "Master_mconsumospesos_delta2"
# [700] "Master_mconsumosdolares_delta1"
# [701] "Master_mconsumosdolares_delta2"
# [702] "Master_mlimitecompra_delta1"
# [703] "Master_mlimitecompra_delta2"
# [704] "Master_madelantopesos_delta1"
# [705] "Master_madelantopesos_delta2"
# [706] "Master_madelantodolares_delta1"
# [707] "Master_madelantodolares_delta2"
# [708] "Master_fultimo_cierre_delta1"
# [709] "Master_fultimo_cierre_delta2"
# [710] "Master_mpagado_delta1"
# [711] "Master_mpagado_delta2"
# [712] "Master_mpagospesos_delta1"
# [713] "Master_mpagospesos_delta2"
# [714] "Master_mpagosdolares_delta1"
# [715] "Master_mpagosdolares_delta2"
# [716] "Master_fechaalta_delta1"
# [717] "Master_fechaalta_delta2"
# [718] "Master_mconsumototal_delta1"
# [719] "Master_mconsumototal_delta2"
# [720] "Master_cconsumos_delta1"
# [721] "Master_cconsumos_delta2"
# [722] "Master_cadelantosefectivo_delta1"
# [723] "Master_cadelantosefectivo_delta2"
# [724] "Master_mpagominimo_delta1"
# [725] "Master_mpagominimo_delta2"
# [726] "Visa_delinquency_delta1"
# [727] "Visa_delinquency_delta2"
# [728] "Visa_status_delta1"
# [729] "Visa_status_delta2"
# [730] "Visa_mfinanciacion_limite_delta1"
# [731] "Visa_mfinanciacion_limite_delta2"
# [732] "Visa_Fvencimiento_delta1"
# [733] "Visa_Fvencimiento_delta2"
# [734] "Visa_Finiciomora_delta1"
# [735] "Visa_Finiciomora_delta2"
# [736] "Visa_msaldototal_delta1"
# [737] "Visa_msaldototal_delta2"
# [738] "Visa_msaldopesos_delta1"
# [739] "Visa_msaldopesos_delta2"
# [740] "Visa_msaldodolares_delta1"
# [741] "Visa_msaldodolares_delta2"
# [742] "Visa_mconsumospesos_delta1"
# [743] "Visa_mconsumospesos_delta2"
# [744] "Visa_mconsumosdolares_delta1"
# [745] "Visa_mconsumosdolares_delta2"
# [746] "Visa_mlimitecompra_delta1"
# [747] "Visa_mlimitecompra_delta2"
# [748] "Visa_madelantopesos_delta1"
# [749] "Visa_madelantopesos_delta2"
# [750] "Visa_madelantodolares_delta1"
# [751] "Visa_madelantodolares_delta2"
# [752] "Visa_fultimo_cierre_delta1"
# [753] "Visa_fultimo_cierre_delta2"
# [754] "Visa_mpagado_delta1"
# [755] "Visa_mpagado_delta2"
# [756] "Visa_mpagospesos_delta1"
# [757] "Visa_mpagospesos_delta2"
# [758] "Visa_mpagosdolares_delta1"
# [759] "Visa_mpagosdolares_delta2"
# [760] "Visa_fechaalta_delta1"
# [761] "Visa_fechaalta_delta2"
# [762] "Visa_mconsumototal_delta1"
# [763] "Visa_mconsumototal_delta2"
# [764] "Visa_cconsumos_delta1"
# [765] "Visa_cconsumos_delta2"
# [766] "Visa_cadelantosefectivo_delta1"
# [767] "Visa_cadelantosefectivo_delta2"
# [768] "Visa_mpagominimo_delta1"
# [769] "Visa_mpagominimo_delta2"
# [770] "kmes_delta1"
# [771] "kmes_delta2"
# [772] "mpayroll_sobre_edad_delta1"
# [773] "mpayroll_sobre_edad_delta2"

# %% [markdown]
# #### 7.3.1.6  FEhist Reduccion dimensionalidad con canaritos
#
# Esta etapa solo se mostrará a la *modalidad Anlista Sr* por algun canal secreto de forma de no confundir a los *Analista Jr*  nni distraer con detalles operativos a la estratégica *Modalidad Gerencial*

# %%
# No se implementa la reduccion de la dimensionalidad con canaritos

# %% [markdown]
# ### 7.3.2 Modelado

# %% [markdown]
# #### 7.3.2.1 Training Strategy
#
# Esta etapa de Workflow de  Training Strategy esta pensada para la *Modalidad Gerencial* que posee el dataset de [202005, 202109]
# <br> Si usted es un Analista, posee el periodo de [201901, 202109] y deberá experimentar en que meses le conviene experimentar
#
# <br> A la *Modalidad Gerencial* no se le complicada la vida con el undersampling de los continua, por eso PARAM$trainingstrategy$training_pct <- 1.0
# <br> Sin embargo, si usted es  *Analista SR* posee un dataset 50 veces ( filas x columnas) más grande que la *Modalidad Gerencial*  y por un tema de velocidad y experimentación más rápida puede llegar a necesitar activar el undersampling de la clase mayoritaria, a pesar de estar corriendo en Google Cloud.

# %% [markdown]
# Se hace una estrategia de entrenamiento muy sencilla, tomando todos los meses posibles, SIN eliminar nada x pandemia ni por ningun otro motivo
#
# * future = 202109  obviamente completo
#
# * final_train =  [ 202005, 202107 ]  con un undersampling de los CONTINUA del 2% por un tema de velocidad
#
# * training
#    * testing = NO HAY
#    * validation =  202107   completo, sin undersampling
#    * training = [ 202005, 202106 ]  donde se consideran el 100% de los CONTINUA

# %%
PARAM$trainingstrategy$validate <- c(202106,202107)

PARAM$trainingstrategy$training <- c(202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005,202004,202003,202002,202002,202001,201912,201911,201910,201909,201908,201907,201906,201905,201904,201903,201902,201901
)

PARAM$trainingstrategy$training_pct <- 0.005


PARAM$trainingstrategy$positivos <- c( "BAJA+1", "BAJA+2")

# %%
# seteo la clase01   1={BAJA+1, BAJA+2}   0={CONTINUA}
dataset[, clase01 := ifelse( clase_ternaria %in% PARAM$trainingstrategy$positivos, 1, 0 )]

# %%
# los campos en los que se entrena
campos_buenos <- copy( setdiff(
    colnames(dataset), c("clase_ternaria","clase01","azar"))
)

# %%
# preparo para que se puede hacer undersampling de los CONTINUA
#  solamente por un tema de VELOCIDAD
set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset[, azar:=runif(nrow(dataset))]

# undersampling de los CONTINUA
dataset[, fold_train :=  foto_mes %in%  PARAM$trainingstrategy$training &
    (clase_ternaria %in% c("BAJA+1", "BAJA+2") |
     azar < PARAM$trainingstrategy$training_pct ) ]


if( !require("lightgbm")) install.packages("lightgbm")
require("lightgbm")

dtrain <- lgb.Dataset(
  data= data.matrix(dataset[fold_train == TRUE, campos_buenos, with = FALSE]),
  label= dataset[fold_train == TRUE, clase01],
  free_raw_data= TRUE
)
# Out:
# Loading required package: lightgbm

# %%
# datos de validation
dvalidate <- lgb.Dataset(
  data= data.matrix(dataset[foto_mes %in% PARAM$trainingstrategy$validate, campos_buenos, with = FALSE]),
  label= dataset[foto_mes %in% PARAM$trainingstrategy$validate, clase01],
  free_raw_data= TRUE
)

nrow(dvalidate)
# Out:
# [1] 328909

# %% [markdown]
# ####  7.3.2.2. Hyperparameter Tuning

# %% [markdown]
# * Clase binaria que se optimiza :  positivos = [ BAJA+1, BAJA+2 ]

# %% [markdown]
# * Metrica que se optimiza **AUC** Area Under Curve de la  ROC Curve
#
# es muy importante notar que intencionalmente  **NO** se está optimizando la funcion de ganancia del problema

# %% [markdown]
# * Cantidad de iteraciones inteligentes de la Optimizacion Bayesiana = **10**

# %% [markdown]
# * Parametros no default, fijos de LightGBM que no se optimizan
#   * max_bin = 31 , Alienigenas Ancestrales contruyeron las pirámides y dejaron a la humanidad en un jeroglifico  *max_bin=31*
#   * feature_fraction = 0.5  para poner algo que generalmente no falla
#   * learning_rate = 0.03  para que aprenda lento

# %% [markdown]
# * Parametros que se optimizan en la Bayesian Optimization
#   * num_leaves  [8, 256]
#   * min_data_in_leaf  [8, 8192]

# %%
# paquetes necesarios para la Bayesian Optimization
if(!require("DiceKriging")) install.packages("DiceKriging")
require("DiceKriging")

if(!require("mlrMBO")) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
#
# Attaching package: ‘ParamHelpers’
#
#
# The following object is masked from ‘package:R.utils’:
#
#     isVector
#
#
#
# Attaching package: ‘mlr’
#
#
# The following objects are masked from ‘package:R.utils’:
#
#     resample, setThreshold
#
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames
#
#
# The following object is masked from ‘package:R.utils’:
#
#     asInt
#
#
#
# Attaching package: ‘smoof’
#
#
# The following objects are masked from ‘package:R.oo’:
#
#     getDescription, getName

# %% [markdown]
# Definición de la Bayesian Optimization
# <br> Si se desea optimizar un hiperparámetro que esta como fijo, debe QUITARSE de param_fijos y agregarse a PARAM$hipeparametertuning$hs

# %%
# valor ridiculamente bajo para que corra rapido en el aula y no molestar a la *Modalidad Gerencial*
PARAM$hipeparametertuning$num_interations <- 50

# parametros fijos del LightGBM
PARAM$lgbm$param_fijos <- list(
  objective= "binary",
  metric= "auc",
  first_metric_only= TRUE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  verbosity= -100,
  force_row_wise= TRUE, # para evitar warning
  seed= PARAM$semilla_primigenia,
  max_bin= 31,
  learning_rate= 0.03,
  feature_fraction= 0.5,
  num_iterations= 2048,  # valor grande, lo limita early_stopping_rounds
  early_stopping_rounds= 200
)

PARAM$hipeparametertuning$hs <- makeParamSet(
  makeIntegerParam("num_leaves", lower = 2L, upper = 1000L),
  makeIntegerParam("min_data_in_leaf", lower = 2L, upper = 8192L)
)

# %% [markdown]
# Función "señora caja negra"  que es llamada para verificar la realidad por la Bayesian Optimization

# %%
# En  x llegan los parmaetros de la bayesiana
#  devuelve la AUC en validate del modelo entrenado
#  en el parametro x llegan los hiperparámetros que se estan optimizando

EstimarGanancia_AUC_lightgbm <- function(x) {

  message(format(Sys.time(), "%a %b %d %X %Y"))

  # uno la lista de hiperparametros : fijos + variables
  param_completo <- c(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelo_train <- lgb.train(
    data= dtrain,
    valids= list(valid = dvalidate),
    eval= "auc",
    param= param_completo,
    verbose= -100
  )

  # recupero la AUC en validation
  AUC <- modelo_train$record_evals$valid$auc$eval[[modelo_train$best_iter]]

  # esta es la forma de devolver un parametro extra
  attr(AUC, "extras") <- list("num_iterations"= modelo_train$best_iter)

  # hago espacio en la memoria
  rm(modelo_train)
  gc(full= TRUE, verbose= FALSE)

  return(AUC)
}

# %% [markdown]
# seteo de la Bayesian Optimization (complejo)
# <br> copiado y pegado de la documentación de la librería

# %%
configureMlr(show.learner.output = FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo
obj.fun <- makeSingleObjectiveFunction(
    fn= EstimarGanancia_AUC_lightgbm, # la funcion que voy a maximizar
    minimize= FALSE, # estoy Maximizando AUC
    noisy= FALSE,
    par.set= PARAM$hipeparametertuning$hs,
    has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
    save.on.disk.at.time= 600,
    save.file.path= "HT.RDATA"
)

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
    ctrl,
    iters= PARAM$hipeparametertuning$num_interations  # cantidad de iteraciones inteligentes
)

# defino el método estandar para la creacion de los puntos iniciales
#   los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit = makeMBOInfillCritEI())

# mas configuraciones
surr.km <- makeLearner(
    "regr.km",
    predict.type= "se",
    covtype= "matern3_2",
    control= list(trace = TRUE)
)

# %% [markdown]
# Corrida de la Bayesian Optimization,  aqui se hace el trabajo pesado
# <br> por favor no se asuste con los warnings que pudieran aparecer
#
# Si corrío a medias y llegó a las iteraciones inteligentes, en el archivo binario HT.RDATA quedó lo ya procesado y es utilizado para retomar la corrida desde lo último que llegó a grabar.

# %%
# inicio la optimizacion bayesiana

if (!file.exists("HT.RDATA")) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue("HT.RDATA") # retomo en caso que ya exista
}
# Out:
# Computing y column(s) for design. Not provided.
#
# Tue Jun 10 19:33:20 2025
#
# Tue Jun 10 19:36:08 2025
#
# Tue Jun 10 19:39:05 2025
#
# Tue Jun 10 19:44:58 2025
#
# Tue Jun 10 19:51:00 2025
#
# Tue Jun 10 19:53:54 2025
#
# [mbo] 0: num_leaves=703; min_data_in_leaf=1170 : y = 0.933 : 169.3 secs : initdesign
#
# [mbo] 0: num_leaves=114; min_data_in_leaf=6684 : y = 0.931 : 176.4 secs : initdesign
#
# [mbo] 0: num_leaves=392; min_data_in_leaf=2263 : y = 0.933 : 164.3 secs : initdesign
#
# [mbo] 0: num_leaves=563; min_data_in_leaf=3149 : y = 0.933 : 189.5 secs : initdesign
#
# [mbo] 0: num_leaves=241; min_data_in_leaf=5057 : y = 0.932 : 182.3 secs : initdesign
#
# [mbo] 0: num_leaves=998; min_data_in_leaf=5609 : y = 0.931 : 179.6 secs : initdesign
#
# [mbo] 0: num_leaves=256; min_data_in_leaf=7249 : y = 0.929 : 174.2 secs : initdesign
#
# [mbo] 0: num_leaves=852; min_data_in_leaf=213 : y = 0.936 : 137.0 secs : initdesign
#
# Saved the current state after iteration 1 in the file HT.RDATA.
#
# Tue Jun 10 19:56:18 2025
#
# [mbo] 1: num_leaves=357; min_data_in_leaf=2 : y = 0.936 : 287.9 secs : infill_ei
#
# Warning message in generateDesign(control$infill.opt.focussearch.points, ps.local, :
# “generateDesign could only produce 540 points instead of 1000!”
# Warning message in generateDesign(control$infill.opt.focussearch.points, ps.local, :
# “generateDesign could only produce 360 points instead of 1000!”
# Warning message in generateDesign(control$infill.opt.focussearch.points, ps.local, :
# “generateDesign could only produce 700 points instead of 1000!”
# Tue Jun 10 20:01:07 2025
#
# [mbo] 2: num_leaves=1000; min_data_in_leaf=2 : y = 0.935 : 447.4 secs : infill_ei
#
# Saved the current state after iteration 3 in the file HT.RDATA.
#
# Tue Jun 10 20:08:40 2025
#
# [mbo] 3: num_leaves=311; min_data_in_leaf=270 : y = 0.935 : 114.3 secs : infill_ei
#
# Tue Jun 10 20:10:34 2025
#
# [mbo] 4: num_leaves=621; min_data_in_leaf=192 : y = 0.936 : 140.1 secs : infill_ei
#
# Tue Jun 10 20:12:55 2025
#
# [mbo] 5: num_leaves=823; min_data_in_leaf=388 : y = 0.935 : 99.5 secs : infill_ei
#
# Warning message in generateDesign(control$infill.opt.focussearch.points, ps.local, :
# “generateDesign could only produce 905 points instead of 1000!”
# Warning message in generateDesign(control$infill.opt.focussearch.points, ps.local, :
# “generateDesign could only produce 762 points instead of 1000!”
# Warning message in generateDesign(control$infill.opt.focussearch.points, ps.local, :
# “generateDesign could only produce 976 points instead of 1000!”
# Tue Jun 10 20:14:35 2025
#
# [mbo] 6: num_leaves=2; min_data_in_leaf=96 : y = 0.924 : 158.4 secs : infill_ei
#
# Tue Jun 10 20:17:13 2025
#
# [mbo] 7: num_leaves=528; min_data_in_leaf=2 : y = 0.935 : 294.3 secs : infill_ei
#
# Saved the current state after iteration 8 in the file HT.RDATA.
#
# Tue Jun 10 20:22:13 2025
#
# [mbo] 8: num_leaves=895; min_data_in_leaf=2 : y = 0.934 : 246.3 secs : infill_ei
#
# Tue Jun 10 20:26:19 2025
#
# [mbo] 9: num_leaves=585; min_data_in_leaf=3 : y = 0.935 : 280.6 secs : infill_ei
#
# Tue Jun 10 20:31:00 2025
#
# [mbo] 10: num_leaves=419; min_data_in_leaf=265 : y = 0.936 : 111.8 secs : infill_ei
#
# Saved the current state after iteration 11 in the file HT.RDATA.
#
# Tue Jun 10 20:32:58 2025
#
# [mbo] 11: num_leaves=459; min_data_in_leaf=2 : y = 0.935 : 234.9 secs : infill_ei
#
# Tue Jun 10 20:36:53 2025
#
# [mbo] 12: num_leaves=365; min_data_in_leaf=747 : y = 0.934 : 102.7 secs : infill_ei
#
# Tue Jun 10 20:38:36 2025
#
# [mbo] 13: num_leaves=1000; min_data_in_leaf=276 : y = 0.936 : 117.2 secs : infill_ei
#
# Tue Jun 10 20:40:34 2025
#
# [mbo] 14: num_leaves=536; min_data_in_leaf=240 : y = 0.936 : 105.0 secs : infill_ei
#
# Tue Jun 10 20:42:19 2025
#
# [mbo] 15: num_leaves=374; min_data_in_leaf=211 : y = 0.935 : 103.9 secs : infill_ei
#
# Saved the current state after iteration 16 in the file HT.RDATA.
#
# Tue Jun 10 20:44:09 2025
#
# [mbo] 16: num_leaves=1000; min_data_in_leaf=1215 : y = 0.933 : 129.4 secs : infill_ei
#
# Tue Jun 10 20:46:19 2025
#
# [mbo] 17: num_leaves=693; min_data_in_leaf=158 : y = 0.935 : 107.8 secs : infill_ei
#
# Tue Jun 10 20:48:07 2025
#
# [mbo] 18: num_leaves=508; min_data_in_leaf=515 : y = 0.934 : 98.0 secs : infill_ei
#
# Tue Jun 10 20:49:45 2025
#
# [mbo] 19: num_leaves=942; min_data_in_leaf=235 : y = 0.935 : 126.7 secs : infill_ei
#
# Tue Jun 10 20:51:52 2025
#
# [mbo] 20: num_leaves=411; min_data_in_leaf=335 : y = 0.935 : 90.2 secs : infill_ei
#
# Tue Jun 10 20:53:22 2025
#
# [mbo] 21: num_leaves=659; min_data_in_leaf=269 : y = 0.935 : 111.5 secs : infill_ei
#
# Saved the current state after iteration 22 in the file HT.RDATA.
#
# Tue Jun 10 20:55:20 2025
#
# [mbo] 22: num_leaves=1000; min_data_in_leaf=645 : y = 0.934 : 96.7 secs : infill_ei
#
# Tue Jun 10 20:56:57 2025
#
# [mbo] 23: num_leaves=432; min_data_in_leaf=216 : y = 0.936 : 128.4 secs : infill_ei
#
# Tue Jun 10 20:59:06 2025
#
# [mbo] 24: num_leaves=302; min_data_in_leaf=1384 : y = 0.933 : 119.0 secs : infill_ei
#
# Tue Jun 10 21:01:05 2025
#
# [mbo] 25: num_leaves=1000; min_data_in_leaf=166 : y = 0.936 : 164.6 secs : infill_ei
#
# Tue Jun 10 21:03:50 2025
#
# [mbo] 27: num_leaves=788; min_data_in_leaf=2571 : y = 0.933 : 194.2 secs : infill_ei
#
# Tue Jun 10 21:09:38 2025
#
# [mbo] 28: num_leaves=163; min_data_in_leaf=2738 : y = 0.933 : 193.2 secs : infill_ei
#
# Tue Jun 10 21:12:52 2025
#
# [mbo] 29: num_leaves=2; min_data_in_leaf=1992 : y = 0.923 : 157.2 secs : infill_ei
#
# Tue Jun 10 21:15:29 2025
#
# [mbo] 30: num_leaves=460; min_data_in_leaf=2668 : y = 0.933 : 163.5 secs : infill_ei
#
# Saved the current state after iteration 31 in the file HT.RDATA.
#
# Tue Jun 10 21:18:18 2025
#
# [mbo] 31: num_leaves=155; min_data_in_leaf=3419 : y = 0.933 : 188.4 secs : infill_ei
#
# Tue Jun 10 21:21:27 2025
#
# [mbo] 32: num_leaves=1000; min_data_in_leaf=2220 : y = 0.933 : 181.0 secs : infill_ei
#
# Tue Jun 10 21:24:28 2025
#
# [mbo] 33: num_leaves=1000; min_data_in_leaf=3456 : y = 0.932 : 189.8 secs : infill_ei
#
# Tue Jun 10 21:27:39 2025
#
# [mbo] 34: num_leaves=587; min_data_in_leaf=3885 : y = 0.932 : 185.4 secs : infill_ei
#
# Saved the current state after iteration 35 in the file HT.RDATA.
#
# Tue Jun 10 21:30:50 2025
#
# [mbo] 35: num_leaves=1000; min_data_in_leaf=4274 : y = 0.932 : 183.7 secs : infill_ei
#
# Tue Jun 10 21:33:54 2025
#
# [mbo] 36: num_leaves=69; min_data_in_leaf=4182 : y = 0.932 : 183.4 secs : infill_ei
#
# Tue Jun 10 21:36:58 2025
#
# [mbo] 37: num_leaves=465; min_data_in_leaf=1012 : y = 0.933 : 93.9 secs : infill_ei
#
# Tue Jun 10 21:38:32 2025
#
# [mbo] 38: num_leaves=596; min_data_in_leaf=4589 : y = 0.932 : 182.8 secs : infill_ei
#
# Saved the current state after iteration 39 in the file HT.RDATA.
#
# Tue Jun 10 21:41:41 2025
#
# [mbo] 39: num_leaves=792; min_data_in_leaf=824 : y = 0.934 : 111.9 secs : infill_ei
#
# Tue Jun 10 21:43:33 2025

# %% [markdown]
# la bayesian optimization ha corrido, extraigo los mejores hiperparametros

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y, -num_iterations)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file="BO_log.txt",
  sep="\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  list(num_leaves, min_data_in_leaf, num_iterations)
]

print(PARAM$out$lgbm$mejores_hiperparametros)

# %% [markdown]
# ### 7.3.3 Produccion

# %% [markdown]
# ### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %% [markdown]
# #### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
PARAM$trainingstrategy$final_train <- c( 202107,
  202106, 202105, 202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005,202004,202003,202002,202002,202001,201912,201911,201910,201909,201908,201907,201906,201905,201904,201903,201902,201901
)
)

dataset[, fold_final_train := foto_mes %in% PARAM$trainingstrategy$final_train ]

# creo el dfinal_train en formato  LightGBM
dfinal_train <- lgb.Dataset(
  data= data.matrix(dataset[fold_final_train == TRUE, campos_buenos, with= FALSE]),
  label= dataset[fold_final_train == TRUE, clase01],
  free_raw_data= TRUE
)

nrow( dfinal_train) # verifico el tamaño

# %% [markdown]
# #### Final Training Hyperparameters

# %%
# uno los parametros fijos y los mejores encontrados de los variables
fijos <- copy(PARAM$lgbm$param_fijos)

# quito lo que optimice en la Bayesian Optimization
fijos$num_iterations <- NULL
fijos$early_stopping_rounds <- NULL

# agrego a los hiperparametros fijos los que encontre con la Bayesian Optimization
param_final <- c(fijos, PARAM$out$lgbm$mejores_hiperparametros)

# %% [markdown]
# #### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
final_model <- lgb.train(
  data= dfinal_train,
  param= param_final,
  verbose= -100
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(final_model, "modelo.txt")

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(final_model))
archivo_importancia <- "impo.txt"

fwrite( tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %% [markdown]
# ### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
PARAM$trainingstrategy$future <- c(202109)

dfuture <- dataset[ foto_mes %in% PARAM$trainingstrategy$future ]

# %%
# aplico final_model   a dfuture

prediccion <- predict(
  final_model,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# #### Tabla Prediccion

# %%
tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion]

# grabo las probabilidad del modelo
#  me va a ser util para hacer Ensembles de modelos
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# Kaggle Competition Submit

# %% [markdown]
# Genero las salidas y hago los submits a Kaggle
# <br>El notebook esta preparado para la Modalidad Gerencial, los analistas deben hacer cambios.
# <br> Los analistas deben cambiar **competencia** a SU competencia  "labo-i-2025-rosario-analista-jr"   o  la original "labo-i-2025-rosario"  para los Senior
# <br> Los cortes  dependen de la cantidad de registros, multiplicar por 2 para los Analistas Jr y por 10 para los Analista Sr
#
# Los Analista Sr luego de meditar cuidadosamente reducirán la cantidad de cortes

# %%
# genero archivos con los  "envios" mejores
# suba TODOS los archivos a Kaggle

PARAM$kaggle$competencia <- "labo-i-2025-rosario"
PARAM$kaggle$cortes <- seq(800, 1300, by = 50)

# ordeno por probabilidad descendente
setorder(tb_prediccion, -prob)

dir.create("kaggle")

for (envios in PARAM$kaggle$cortes) {

  tb_prediccion[, Predicted := 0L] # seteo inicial a 0
  tb_prediccion[1:envios, Predicted := 1L] # marclo los primeros

  archivo_kaggle <- paste0("./kaggle/KA", PARAM$experimento, "_", envios, ".csv")

  # grabo el archivo
  fwrite(tb_prediccion[, list(numero_de_cliente, Predicted)],
    file= archivo_kaggle,
    sep= ","
  )

  # subida a Kaggle, armo la linea de comando
  comando <- "kaggle competitions submit"
  competencia <- paste("-c", PARAM$kaggle$competencia)
  arch <- paste( "-f", archivo_kaggle)

  mensaje <- paste0("-m 'envios=", envios,
  "  semilla=", PARAM$semilla_primigenia,
    "'" )

  linea <- paste( comando, competencia, arch, mensaje)

  salida <- system(linea, intern=TRUE) # el submit a Kaggle
  cat(salida, "\n")
}

# %%
# grabo los parametros
if( !require("yaml")) install.packages("yaml")
require("yaml")

write_yaml( PARAM, file="PARAM.yml")

# %%
format(Sys.time(), "%a %b %d %X %Y")
